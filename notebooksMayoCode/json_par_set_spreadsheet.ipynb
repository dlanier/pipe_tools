# %% [markdown]
# # Collect & View all "json" file variables defined in a directory of such
#     * actually defined in the config files
#     * some files may be empty

# %%
import os
import sys
import numpy as np
import pandas as pd

sys.path.insert(1, '../src')
import yaml_utility as yut

user_home = '/Users/mojo/git_clone/SAM_BAM/'
json_dir = os.path.join(user_home, 'MayomicsVC/json_inputs')

print(json_dir)
print('json_dir Exists?',
      os.path.isdir(json_dir))
# Out:
# /Users/mojo/git_clone/SAM_BAM/MayomicsVC/json_inputs
# json_dir Exists? True

# %%
json_df = yut.get_yaml_df(json_dir)
json_df
# Out:
#                                                      InputsTestWorkflow1and2a.json
# MasterWF.DB2a.SampleName                                          NEAT_chr20_21_22
# MasterWF.DB1.Sentieon            /usr/local/apps/bioapps/sentieon/sentieon-geno...
# MasterWF.DB1.TrimSeqScript       /projects/mgc/Project_1/ram/CromwellWDL_WorkFl...
# MasterWF.DB1.InputRead2          /projects/mgc/Project_1/KIK/MayomicsVC/NEAT_R2...
# MasterWF.DB1.RefAnn              /projects/mgc/Project_1/KIK/Testing_Sentieon_2...
# MasterWF.DB2a.KnownSitesIdx      /projects/bioinformatics/DataPacks/human/gatk_...
# MasterWF.DB1.AlignmentScript     /projects/mgc/Project_1/ram/CromwellWDL_WorkFl...
# MasterWF.DB2a.DebugMode
# MasterWF.DB1.RefPac              /projects/mgc/Project_1/KIK/Testing_Sentieon_2...
# MasterWF.DB1.Adapters            /projects/bioinformatics/MRW/MayomicsVC-Dev/te...
# MasterWF.DB2a.HaplotyperScript   /projects/mgc/Project_1/ram/CromwellWDL_WorkFl...
# ...
