# %% [markdown]
# <img src="images/HookahCaterpillerAliceInWDLand.jpg" width="200" height="300"> <br>
# # COURT OF aggravated PROGRAMING
#
#                 v
#
# # MAYOMICSVC SRC PYTHON CONFIG PARSER
#
#                 aka
#
# # CONFIG PARSER PARSING et al.
#
#         I, the undersigned complainant being duly sworn state the following is true and correct
#         to the best of my knowledge and belief.
#
# #### Count One
#     From on or about November, 2018 to the present in the district of UIUC, in or about the offices NCSA, the above named code did proceed to aggravate, irritate, insult, inflame and annoy hapless techno-peasents endevoring to translate friviolous file formats in the employ of responsible parties.
#
# #### Count Two
#     Violation of Object Oriented Principles - "Object" in question is best not an extensible data type.
#     * Modular - NOT. Scattered mess of files is not modularity
#     * Reusability - NOT. Not even useable
#     * Maintainability - REALLY NOT. Spaghetti code speaks for itself.
#     * Polymorphism - NOT. Special case program - not adaptable.
#
# #### Count Three
#     Violation of statutes by include validator, key_types, magic-strings and numerous others.
#     * key_types.json is redundant - contrary to WOMTOOL generated template.json concept.
#     * contradicts inter-operability standards and standard library functions
#
# ##### exempli gratia
# ```json
# {
#     "GermlineMasterWF.align.ALIGN_paired.BWAExtraOptionsString": "\"'-M'\"",
#     "GermlineMasterWF.haplotype.HaplotyperExtraOptionsString": "\"'--emit_mode variant --gq_bands 1-60,60-99/19,99 --min_base_qual 10 --pcr_indel_model CONSERVATIVE --phasing 1 --ploidy 2 --prune_factor 2'\"",
#     "GermlineMasterWF.vqsr.AnnotateText": "\"'--annotation DP --annotation QD --annotation FS --annotation SOR --annotation MQ --annotation MQRankSum --annotation ReadPosRankSum'\"",
#     "GermlineMasterWF.vqsr.VqsrIndelResourceString": "\"'--resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf --resource_param dbsnp,known=true,training=false,truth=false,prior=2.0 --resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Mills_and_1000G_gold_standard.indels.hg38.vcf --resource_param Mills,known=false,training=true,truth=true,prior=12.0'\"",
#     "GermlineMasterWF.vqsr.VqsrSnpResourceString": "\"'--resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/1000G_phase1.snps.high_confidence.hg38.vcf.gz --resource_param 1000G,known=false,training=true,truth=false,prior=10.0 --resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/1000G_omni2.5.hg38.vcf.gz --resource_param omni,known=false,training=true,truth=false,prior=12.0 --resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf --resource_param dbsnp,known=true,training=false,truth=false,prior=2.0 --resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/hapmap_3.3.hg38.vcf.gz --resource_param hapmap,known=false,training=true,truth=true,prior=15.0'\""
# }
# ```
# ##### of templated types:
# ```json
# {
#     "GermlineMasterWF.align.ALIGN_paired.BWAExtraOptionsString": "String",
#     "GermlineMasterWF.align.ALIGN_single.BWAExtraOptionsString": "String",
#     "GermlineMasterWF.haplotype.HaplotyperExtraOptionsString": "String",
#     "GermlineMasterWF.vqsr.AnnotateText": "String",
#     "GermlineMasterWF.vqsr.VqsrIndelResourceString": "String",
#     "GermlineMasterWF.vqsr.VqsrSnpResourceString": "String"
# }
# ```
# ##### primarily foune in: run_info.txt
# ```bash
# BWAExtraOptionsString=""'-M'""
#
# HaplotyperExtraOptionsString=""'--emit_mode variant --gq_bands 1-60,60-99/19,99 --min_base_qual 10 --pcr_indel_model CONSERVATIVE --phasing 1 --ploidy 2 --prune_factor 2'""
#
# AnnotateText=""'--annotation DP --annotation QD --annotation FS --annotation SOR --annotation MQ --annotation MQRankSum --annotation ReadPosRankSum'""
#
# VqsrIndelResourceString=""'--resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf --resource_param dbsnp,known=true,training=false,truth=false,prior=2.0 --resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Mills_and_1000G_gold_standard.indels.hg38.vcf --resource_param Mills,known=false,training=true,truth=true,prior=12.0'""
#
# VqsrSnpResourceString=""'--resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/1000G_phase1.snps.high_confidence.hg38.vcf.gz --resource_param 1000G,known=false,training=true,truth=false,prior=10.0 --resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/1000G_omni2.5.hg38.vcf.gz --resource_param omni,known=false,training=true,truth=false,prior=12.0 --resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf --resource_param dbsnp,known=true,training=false,truth=false,prior=2.0 --resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/hapmap_3.3.hg38.vcf.gz --resource_param hapmap,known=false,training=true,truth=true,prior=15.0'""
# ```
