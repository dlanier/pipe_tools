# %% [markdown]
# [json python std lib](https://docs.python.org/3/library/json.html) <br>
# # Bottom Line:
# They all open json files as text with or without double quotes. <br>
# The readlines( ) option drops the newline characters and returns a list. <br>
# The splitlines( ) option keeps the newline charcters and returns a list. <br>
# The json.loads( ) removes newline characters and constructs a propper python dict. <br>

# %% [markdown]
# # Open the json file - compare methods -- aka first mistake:
# * output is dictionary of single-quoted strings
# * the single quotes are superfluous
# * json.loads as a list of lines or yaml avoids the single quotes.
#
# [Current](https://git.ncsa.illinois.edu/mayomics/MayomicsVC/blob/master/src/python/util/util.py) <br>
#
# ```python
# import sys
# import json
#
# def read_json_file(json_file, project_logger, json_not_found_error_code, json_bad_format_error_code):
#     """
#     Reads a JSON formatted file, and returns its contents as a Python dictionary
#
#     Inputs:
#         The json file
#         The project logger (for error messages to get passed to)
#         The error code if a JSON file is not found
#         The error code if a JSON file is improperly formatted
#     """
#     try:
#         # Open the file
#         with open(json_file) as F:
#             # Read the file's contents as a string
#             json_str = F.read()
#             # Return the data as a Python dictionary
#             return json.loads(json_str)
#     except FileNotFoundError:
#         project_logger.log_error(
#             json_not_found_error_code,
#             'Could not open json file "' + str(json_file) + '": JSON file could not be found'
#         )
#         sys.exit(1)
#     except json.decoder.JSONDecodeError:
#         project_logger.log_error(
#             json_bad_format_error_code,
#             'Could not open json file "' + str(json_file) + '": JSON file not formatted properly'
#         )
#         sys.exit(1)
#
#
# def read_input_file(self, file_path):
#
#     try:
#         with open(file_path, "r") as F:
#             return F.read().splitlines()
#
#     except FileNotFoundError:
#         self.project_logger.log_error("E.par.Fil.1", 'Input file "' + str(file_path) +
#                                       '" could not be found')
#         sys.exit(1)
# ```

# %%
import os
import sys

path_to_development_code_modules = '.'
sys.path.insert(1, path_to_development_code_modules)
from womtool_template_fill_in import *

import json

def read_raw_hee_haw(file_path):
    
    with open(file_path, "r") as F:
        return F.read().splitlines()


def read_json_raw(json_full_filename):
    
    with open(json_full_filename, 'r') as fh:
        lines = fh.readlines()
        
    return lines


def dict_from_json_file(json_full_filename):
    # lines is list with newline chars left in
    lines = read_json_raw(json_full_filename)
    S = ''
    for line in lines:
        S += line.strip()
    
    return json.loads(S)

# %%
jsonTemplate = '../data/GermlineParameters/Jsons/GermlineMasterWorkflow.template.json'
json_filled_in = '../data/GermlineParameters/Jsons/GermlineMasterWorkflow.BAK.FilledIn.json'

#                   Sets all cells on the page:
json_compare_file = jsonTemplate
print(os.path.isfile(json_compare_file))
# Out:
# True

# %%
print('File:\n%s\nwith method:\nread_raw_hee_haw\n'%(json_compare_file))
lines = read_raw_hee_haw(json_compare_file)
print(type(lines),'\n\n')

for line in lines:
    print(line)
# Out:
# File:
# ../data/GermlineParameters/Jsons/GermlineMasterWorkflow.template.json
# with method:
# read_raw_hee_haw
#
# <class 'list'>
#
#
# {
#   "GermlineMasterWF.realign.RealignSoftMemLimit": "String",
#   "GermlineMasterWF.bqsr.DebugMode": "String",
#   "GermlineMasterWF.Bqsr": "Boolean",
#   "GermlineMasterWF.vqsr.VqsrHardMemLimit": "String",
#   "GermlineMasterWF.align.ALIGN_paired.BashSharedFunctions": "File",
#   "GermlineMasterWF.dedup.BashPreamble": "File",
#   "GermlineMasterWF.merge.MergeBamEnvProfile": "File",
#   "GermlineMasterWF.DHVC.BashPreamble": "File",
#   "GermlineMasterWF.bqsr.BqsrSoftMemLimit": "String",
#   "GermlineMasterWF.align.ALIGN_single.BashPreamble": "File",
#   "GermlineMasterWF.bqsr.BashSharedFunctions": "File",
#   "GermlineMasterWF.align.ALIGN_paired.Sentieon": "String",
#   "GermlineMasterWF.align.ALIGN_paired.CenterName": "String",
#   "GermlineMasterWF.vqsr.VqsrSoftMemLimit": "String",
#   "GermlineMasterWF.bqsr.BqsrHardMemLimit": "String",
#   "GermlineMasterWF.align.ALIGN_paired.AlignEnvProfile": "File",
#   "GermlineMasterWF.vqsr.AnnotateText": "String",
#   "GermlineMasterWF.align.ALIGN_paired.RefPac": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSoftMemLimit": "String",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.BashSharedFunctions": "File",
#   "GermlineMasterWF.bqsr.Ref": "File",
#   "GermlineMasterWF.haplotype.HaplotyperSoftMemLimit": "String",
#   "GermlineMasterWF.bqsr.BqsrKnownSites": "String",
#   "GermlineMasterWF.realign.RealignHardMemLimit": "String",
#   "GermlineMasterWF.dedup.DebugMode": "String",
#   "GermlineMasterWF.dedup.SentieonThreads": "String",
#   "GermlineMasterWF.bqsr.SentieonThreads": "String",
#   "GermlineMasterWF.haplotype.RefFai": "File",
#   "GermlineMasterWF.haplotype.HaplotyperEnvProfile": "File",
#   "GermlineMasterWF.realign.SentieonThreads": "String",
#   "GermlineMasterWF.MarkDuplicates": "Boolean",
#   "GermlineMasterWF.haplotype.BashPreamble": "File",
#   "GermlineMasterWF.align.ALIGN_single.RefBwt": "File",
#   "GermlineMasterWF.align.ALIGN_paired.Platform": "String",
#   "GermlineMasterWF.realign.RealignmentScript": "File",
#   "GermlineMasterWF.NormalInputReads": "Array[Array[File]]",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.TrimHardMemLimit": "String",
#   "GermlineMasterWF.realign.RefFai": "File",
#   "GermlineMasterWF.merge.BashPreamble": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.BashSharedFunctions": "File",
#   "GermlineMasterWF.realign.DebugMode": "String",
#   "GermlineMasterWF.DHVC.WorkflowJson": "File",
#   "GermlineMasterWF.align.ALIGN_paired.PairedEnd": "Boolean",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.BashPreamble": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.TrimEnvProfile": "File",
#   "GermlineMasterWF.merge.MergeBamScript": "File",
#   "GermlineMasterWF.align.ALIGN_paired.RefSa": "File",
#   "GermlineMasterWF.bqsr.SampleName": "String",
#   "GermlineMasterWF.dedup.DedupScript": "File",
#   "GermlineMasterWF.haplotype.Ref": "File",
#   "GermlineMasterWF.align.ALIGN_single.AlignSoftMemLimit": "String",
#   "GermlineMasterWF.bqsr.RefFai": "File",
#   "GermlineMasterWF.DAB.DebugMode": "String",
#   "GermlineMasterWF.dedup.Sentieon": "String",
#   "GermlineMasterWF.haplotype.BashSharedFunctions": "File",
#   "GermlineMasterWF.align.ALIGN_single.Sentieon": "String",
#   "GermlineMasterWF.align.ALIGN_paired.AlignmentScript": "File",
#   "GermlineMasterWF.align.ALIGN_single.RefPac": "File",
#   "GermlineMasterWF.DAB.BashSharedFunctions": "File",
#   "GermlineMasterWF.DHVC.DeliveryHaplotyperVC_Script": "File",
#   "GermlineMasterWF.haplotype.HaplotyperVCFSourceField": "String",
#   "GermlineMasterWF.haplotype.DebugMode": "String",
#   "GermlineMasterWF.align.ALIGN_paired.AlignSoftMemLimit": "String",
#   "GermlineMasterWF.haplotype.DBSNP": "File",
#   "GermlineMasterWF.vqsr.VqsrIndelResourceString": "String",
#   "GermlineMasterWF.DHVC.DeliveryFolder_HaplotyperVC": "String",
#   "GermlineMasterWF.DAB.DeliveryFolder_Alignment": "String",
#   "GermlineMasterWF.vqsr.VqsrScript": "File",
#   "GermlineMasterWF.align.PlatformUnit": "Array[String]",
#   "GermlineMasterWF.align.ALIGN_paired.RefBwt": "File",
#   "GermlineMasterWF.align.ALIGN_single.DebugMode": "String",
#   "GermlineMasterWF.trimseq.PairedEnd": "Boolean",
#   "GermlineMasterWF.haplotype.HaplotyperScript": "File",
#   "GermlineMasterWF.Vqsr": "Boolean",
#   "GermlineMasterWF.vqsr.VqsrSnpResourceString": "String",
#   "GermlineMasterWF.dedup.DedupEnvProfile": "File",
#   "GermlineMasterWF.align.ALIGN_single.RefAmb": "File",
#   "GermlineMasterWF.realign.BashPreamble": "File",
#   "GermlineMasterWF.DAB.SampleName": "String",
#   "GermlineMasterWF.align.ALIGN_single.CenterName": "String",
#   "GermlineMasterWF.merge.SampleName": "String",
#   "GermlineMasterWF.realign.Sentieon": "String",
#   "GermlineMasterWF.bqsr.Sentieon": "String",
#   "GermlineMasterWF.vqsr.SentieonThreads": "String",
#   "GermlineMasterWF.align.ALIGN_single.Platform": "String",
#   "GermlineMasterWF.realign.RealignmentKnownSites": "String",
#   "GermlineMasterWF.bqsr.BqsrScript": "File",
#   "GermlineMasterWF.align.ALIGN_single.AlignHardMemLimit": "String",
#   "GermlineMasterWF.DHVC.DebugMode": "String",
#   "GermlineMasterWF.haplotype.HaplotyperExtraOptionsString": "String",
#   "GermlineMasterWF.vqsr.VqsrEnvProfile": "File",
#   "GermlineMasterWF.align.ALIGN_single.AlignEnvProfile": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSeqScript": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdaptThreads": "String",
#   "GermlineMasterWF.bqsr.BqsrEnvProfile": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.BashPreamble": "File",
#   "GermlineMasterWF.vqsr.DebugMode": "String",
#   "GermlineMasterWF.align.ALIGN_paired.BashPreamble": "File",
#   "GermlineMasterWF.align.ALIGN_single.SentieonThreads": "String",
#   "GermlineMasterWF.align.ALIGN_paired.DebugMode": "String",
#   "GermlineMasterWF.align.ALIGN_paired.Library": "String",
#   "GermlineMasterWF.vqsr.Ref": "File",
#   "GermlineMasterWF.realign.BashSharedFunctions": "File",
#   "GermlineMasterWF.align.ALIGN_single.PairedEnd": "Boolean",
#   "GermlineMasterWF.trimseq.SampleName": "String",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSeqScript": "File",
#   "GermlineMasterWF.align.ALIGN_paired.AlignHardMemLimit": "String",
#   "GermlineMasterWF.realign.SampleName": "String",
#   "GermlineMasterWF.DAB.DeliveryAlignment_Script": "File",
#   "GermlineMasterWF.haplotype.HaplotyperHardMemLimit": "String",
#   "GermlineMasterWF.realign.Ref": "File",
#   "GermlineMasterWF.haplotype.SampleName": "String",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.Adapters": "File",
#   "GermlineMasterWF.align.ALIGN_paired.Ref": "File",
#   "GermlineMasterWF.align.ALIGN_single.RefSa": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimHardMemLimit": "String",
#   "GermlineMasterWF.align.ALIGN_paired.ChunkSizeInBases": "String",
#   "GermlineMasterWF.align.ALIGN_single.RefAnn": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdaptThreads": "String",
#   "GermlineMasterWF.merge.SentieonThreads": "String",
#   "GermlineMasterWF.dedup.DedupHardMemLimit": "String",
#   "GermlineMasterWF.dedup.SampleName": "String",
#   "GermlineMasterWF.vqsr.RefFai": "File",
#   "GermlineMasterWF.align.ALIGN_paired.RefAnn": "File",
#   "GermlineMasterWF.DHVC.SampleName": "String",
#   "GermlineMasterWF.vqsr.BashSharedFunctions": "File",
#   "GermlineMasterWF.align.PairedEnd": "Boolean",
#   "GermlineMasterWF.align.ALIGN_single.Library": "String",
#   "GermlineMasterWF.bqsr.BashPreamble": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.DebugMode": "String",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdapt": "String",
#   "GermlineMasterWF.haplotype.Sentieon": "String",
#   "GermlineMasterWF.vqsr.SampleName": "String",
#   "GermlineMasterWF.merge.DebugMode": "String",
#   "GermlineMasterWF.DAB.WorkflowJson": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.PairedEnd": "Boolean",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.PairedEnd": "Boolean",
#   "GermlineMasterWF.align.SampleName": "String",
#   "GermlineMasterWF.align.ALIGN_single.ChunkSizeInBases": "String",
#   "GermlineMasterWF.Trimming": "Boolean",
#   "GermlineMasterWF.vqsr.BashPreamble": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdapt": "String",
#   "GermlineMasterWF.haplotype.DBSNPIdx": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSoftMemLimit": "String",
#   "GermlineMasterWF.align.ALIGN_single.BashSharedFunctions": "File",
#   "GermlineMasterWF.dedup.BashSharedFunctions": "File",
#   "GermlineMasterWF.DAB.BashPreamble": "File",
#   "GermlineMasterWF.DHVC.BashSharedFunctions": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.DebugMode": "String",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimEnvProfile": "File",
#   "GermlineMasterWF.realign.RealignEnvProfile": "File",
#   "GermlineMasterWF.align.ALIGN_paired.RefAmb": "File",
#   "GermlineMasterWF.haplotype.SentieonThreads": "String",
#   "GermlineMasterWF.align.ALIGN_paired.BWAExtraOptionsString": "String",
#   "GermlineMasterWF.align.ALIGN_paired.SentieonThreads": "String",
#   "GermlineMasterWF.align.ALIGN_single.AlignmentScript": "File",
#   "GermlineMasterWF.merge.MergeHardMemLimit": "String",
#   "GermlineMasterWF.align.ALIGN_single.BWAExtraOptionsString": "String",
#   "GermlineMasterWF.vqsr.Sentieon": "String",
#   "GermlineMasterWF.merge.Sentieon": "String",
#   "GermlineMasterWF.merge.MergeSoftMemLimit": "String",
#   "GermlineMasterWF.align.ALIGN_single.Ref": "File",
#   "GermlineMasterWF.trimseq.TRIMSEQ_paired.Adapters": "File",
#   "GermlineMasterWF.dedup.DedupSoftMemLimit": "String",
#   "GermlineMasterWF.merge.BashSharedFunctions": "File"
# }

# %%
print('File:\n%s\nwith method:\nread_json_raw\n\n'%(json_compare_file))
lines = read_json_raw(json_compare_file)
print(type(lines),'\n\n')

for line in lines:
    print(line.strip())
# Out:
# File:
# ../data/GermlineParameters/Jsons/GermlineMasterWorkflow.template.json
# with method:
# read_json_raw
#
#
# <class 'list'>
#
#
# {
# "GermlineMasterWF.realign.RealignSoftMemLimit": "String",
# "GermlineMasterWF.bqsr.DebugMode": "String",
# "GermlineMasterWF.Bqsr": "Boolean",
# "GermlineMasterWF.vqsr.VqsrHardMemLimit": "String",
# "GermlineMasterWF.align.ALIGN_paired.BashSharedFunctions": "File",
# "GermlineMasterWF.dedup.BashPreamble": "File",
# "GermlineMasterWF.merge.MergeBamEnvProfile": "File",
# "GermlineMasterWF.DHVC.BashPreamble": "File",
# "GermlineMasterWF.bqsr.BqsrSoftMemLimit": "String",
# "GermlineMasterWF.align.ALIGN_single.BashPreamble": "File",
# "GermlineMasterWF.bqsr.BashSharedFunctions": "File",
# "GermlineMasterWF.align.ALIGN_paired.Sentieon": "String",
# "GermlineMasterWF.align.ALIGN_paired.CenterName": "String",
# "GermlineMasterWF.vqsr.VqsrSoftMemLimit": "String",
# "GermlineMasterWF.bqsr.BqsrHardMemLimit": "String",
# "GermlineMasterWF.align.ALIGN_paired.AlignEnvProfile": "File",
# "GermlineMasterWF.vqsr.AnnotateText": "String",
# "GermlineMasterWF.align.ALIGN_paired.RefPac": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSoftMemLimit": "String",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.BashSharedFunctions": "File",
# "GermlineMasterWF.bqsr.Ref": "File",
# "GermlineMasterWF.haplotype.HaplotyperSoftMemLimit": "String",
# "GermlineMasterWF.bqsr.BqsrKnownSites": "String",
# "GermlineMasterWF.realign.RealignHardMemLimit": "String",
# "GermlineMasterWF.dedup.DebugMode": "String",
# "GermlineMasterWF.dedup.SentieonThreads": "String",
# "GermlineMasterWF.bqsr.SentieonThreads": "String",
# "GermlineMasterWF.haplotype.RefFai": "File",
# "GermlineMasterWF.haplotype.HaplotyperEnvProfile": "File",
# "GermlineMasterWF.realign.SentieonThreads": "String",
# "GermlineMasterWF.MarkDuplicates": "Boolean",
# "GermlineMasterWF.haplotype.BashPreamble": "File",
# "GermlineMasterWF.align.ALIGN_single.RefBwt": "File",
# "GermlineMasterWF.align.ALIGN_paired.Platform": "String",
# "GermlineMasterWF.realign.RealignmentScript": "File",
# "GermlineMasterWF.NormalInputReads": "Array[Array[File]]",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.TrimHardMemLimit": "String",
# "GermlineMasterWF.realign.RefFai": "File",
# "GermlineMasterWF.merge.BashPreamble": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.BashSharedFunctions": "File",
# "GermlineMasterWF.realign.DebugMode": "String",
# "GermlineMasterWF.DHVC.WorkflowJson": "File",
# "GermlineMasterWF.align.ALIGN_paired.PairedEnd": "Boolean",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.BashPreamble": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.TrimEnvProfile": "File",
# "GermlineMasterWF.merge.MergeBamScript": "File",
# "GermlineMasterWF.align.ALIGN_paired.RefSa": "File",
# "GermlineMasterWF.bqsr.SampleName": "String",
# "GermlineMasterWF.dedup.DedupScript": "File",
# "GermlineMasterWF.haplotype.Ref": "File",
# "GermlineMasterWF.align.ALIGN_single.AlignSoftMemLimit": "String",
# "GermlineMasterWF.bqsr.RefFai": "File",
# "GermlineMasterWF.DAB.DebugMode": "String",
# "GermlineMasterWF.dedup.Sentieon": "String",
# "GermlineMasterWF.haplotype.BashSharedFunctions": "File",
# "GermlineMasterWF.align.ALIGN_single.Sentieon": "String",
# "GermlineMasterWF.align.ALIGN_paired.AlignmentScript": "File",
# "GermlineMasterWF.align.ALIGN_single.RefPac": "File",
# "GermlineMasterWF.DAB.BashSharedFunctions": "File",
# "GermlineMasterWF.DHVC.DeliveryHaplotyperVC_Script": "File",
# "GermlineMasterWF.haplotype.HaplotyperVCFSourceField": "String",
# "GermlineMasterWF.haplotype.DebugMode": "String",
# "GermlineMasterWF.align.ALIGN_paired.AlignSoftMemLimit": "String",
# "GermlineMasterWF.haplotype.DBSNP": "File",
# "GermlineMasterWF.vqsr.VqsrIndelResourceString": "String",
# "GermlineMasterWF.DHVC.DeliveryFolder_HaplotyperVC": "String",
# "GermlineMasterWF.DAB.DeliveryFolder_Alignment": "String",
# "GermlineMasterWF.vqsr.VqsrScript": "File",
# "GermlineMasterWF.align.PlatformUnit": "Array[String]",
# "GermlineMasterWF.align.ALIGN_paired.RefBwt": "File",
# "GermlineMasterWF.align.ALIGN_single.DebugMode": "String",
# "GermlineMasterWF.trimseq.PairedEnd": "Boolean",
# "GermlineMasterWF.haplotype.HaplotyperScript": "File",
# "GermlineMasterWF.Vqsr": "Boolean",
# "GermlineMasterWF.vqsr.VqsrSnpResourceString": "String",
# "GermlineMasterWF.dedup.DedupEnvProfile": "File",
# "GermlineMasterWF.align.ALIGN_single.RefAmb": "File",
# "GermlineMasterWF.realign.BashPreamble": "File",
# "GermlineMasterWF.DAB.SampleName": "String",
# "GermlineMasterWF.align.ALIGN_single.CenterName": "String",
# "GermlineMasterWF.merge.SampleName": "String",
# "GermlineMasterWF.realign.Sentieon": "String",
# "GermlineMasterWF.bqsr.Sentieon": "String",
# "GermlineMasterWF.vqsr.SentieonThreads": "String",
# "GermlineMasterWF.align.ALIGN_single.Platform": "String",
# "GermlineMasterWF.realign.RealignmentKnownSites": "String",
# "GermlineMasterWF.bqsr.BqsrScript": "File",
# "GermlineMasterWF.align.ALIGN_single.AlignHardMemLimit": "String",
# "GermlineMasterWF.DHVC.DebugMode": "String",
# "GermlineMasterWF.haplotype.HaplotyperExtraOptionsString": "String",
# "GermlineMasterWF.vqsr.VqsrEnvProfile": "File",
# "GermlineMasterWF.align.ALIGN_single.AlignEnvProfile": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSeqScript": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdaptThreads": "String",
# "GermlineMasterWF.bqsr.BqsrEnvProfile": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.BashPreamble": "File",
# "GermlineMasterWF.vqsr.DebugMode": "String",
# "GermlineMasterWF.align.ALIGN_paired.BashPreamble": "File",
# "GermlineMasterWF.align.ALIGN_single.SentieonThreads": "String",
# "GermlineMasterWF.align.ALIGN_paired.DebugMode": "String",
# "GermlineMasterWF.align.ALIGN_paired.Library": "String",
# "GermlineMasterWF.vqsr.Ref": "File",
# "GermlineMasterWF.realign.BashSharedFunctions": "File",
# "GermlineMasterWF.align.ALIGN_single.PairedEnd": "Boolean",
# "GermlineMasterWF.trimseq.SampleName": "String",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSeqScript": "File",
# "GermlineMasterWF.align.ALIGN_paired.AlignHardMemLimit": "String",
# "GermlineMasterWF.realign.SampleName": "String",
# "GermlineMasterWF.DAB.DeliveryAlignment_Script": "File",
# "GermlineMasterWF.haplotype.HaplotyperHardMemLimit": "String",
# "GermlineMasterWF.realign.Ref": "File",
# "GermlineMasterWF.haplotype.SampleName": "String",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.Adapters": "File",
# "GermlineMasterWF.align.ALIGN_paired.Ref": "File",
# "GermlineMasterWF.align.ALIGN_single.RefSa": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimHardMemLimit": "String",
# "GermlineMasterWF.align.ALIGN_paired.ChunkSizeInBases": "String",
# "GermlineMasterWF.align.ALIGN_single.RefAnn": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdaptThreads": "String",
# "GermlineMasterWF.merge.SentieonThreads": "String",
# "GermlineMasterWF.dedup.DedupHardMemLimit": "String",
# "GermlineMasterWF.dedup.SampleName": "String",
# "GermlineMasterWF.vqsr.RefFai": "File",
# "GermlineMasterWF.align.ALIGN_paired.RefAnn": "File",
# "GermlineMasterWF.DHVC.SampleName": "String",
# "GermlineMasterWF.vqsr.BashSharedFunctions": "File",
# "GermlineMasterWF.align.PairedEnd": "Boolean",
# "GermlineMasterWF.align.ALIGN_single.Library": "String",
# "GermlineMasterWF.bqsr.BashPreamble": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.DebugMode": "String",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdapt": "String",
# "GermlineMasterWF.haplotype.Sentieon": "String",
# "GermlineMasterWF.vqsr.SampleName": "String",
# "GermlineMasterWF.merge.DebugMode": "String",
# "GermlineMasterWF.DAB.WorkflowJson": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.PairedEnd": "Boolean",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.PairedEnd": "Boolean",
# "GermlineMasterWF.align.SampleName": "String",
# "GermlineMasterWF.align.ALIGN_single.ChunkSizeInBases": "String",
# "GermlineMasterWF.Trimming": "Boolean",
# "GermlineMasterWF.vqsr.BashPreamble": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdapt": "String",
# "GermlineMasterWF.haplotype.DBSNPIdx": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSoftMemLimit": "String",
# "GermlineMasterWF.align.ALIGN_single.BashSharedFunctions": "File",
# "GermlineMasterWF.dedup.BashSharedFunctions": "File",
# "GermlineMasterWF.DAB.BashPreamble": "File",
# "GermlineMasterWF.DHVC.BashSharedFunctions": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.DebugMode": "String",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimEnvProfile": "File",
# "GermlineMasterWF.realign.RealignEnvProfile": "File",
# "GermlineMasterWF.align.ALIGN_paired.RefAmb": "File",
# "GermlineMasterWF.haplotype.SentieonThreads": "String",
# "GermlineMasterWF.align.ALIGN_paired.BWAExtraOptionsString": "String",
# "GermlineMasterWF.align.ALIGN_paired.SentieonThreads": "String",
# "GermlineMasterWF.align.ALIGN_single.AlignmentScript": "File",
# "GermlineMasterWF.merge.MergeHardMemLimit": "String",
# "GermlineMasterWF.align.ALIGN_single.BWAExtraOptionsString": "String",
# "GermlineMasterWF.vqsr.Sentieon": "String",
# "GermlineMasterWF.merge.Sentieon": "String",
# "GermlineMasterWF.merge.MergeSoftMemLimit": "String",
# "GermlineMasterWF.align.ALIGN_single.Ref": "File",
# "GermlineMasterWF.trimseq.TRIMSEQ_paired.Adapters": "File",
# "GermlineMasterWF.dedup.DedupSoftMemLimit": "String",
# "GermlineMasterWF.merge.BashSharedFunctions": "File"
# }

# %%
print('File:\n%s\nwith method:\ndict_from_json_file\n'%(json_compare_file))
proppa_dict = {}

if os.path.isfile(json_compare_file) == True:
    proppa_dict = dict_from_json_file(json_compare_file)
    
print(type(proppa_dict), len(proppa_dict), 'keys\n')
    
for k,v in proppa_dict.items():
    print('%s:\n\t%s\n'%(k,v))
# Out:
# File:
# ../data/GermlineParameters/Jsons/GermlineMasterWorkflow.template.json
# with method:
# dict_from_json_file
#
# <class 'dict'> 165 keys
#
# GermlineMasterWF.realign.RealignSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.DebugMode:
# 	String
#
# GermlineMasterWF.Bqsr:
# 	Boolean
#
# GermlineMasterWF.vqsr.VqsrHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.dedup.BashPreamble:
# 	File
#
# GermlineMasterWF.merge.MergeBamEnvProfile:
# 	File
#
# GermlineMasterWF.DHVC.BashPreamble:
# 	File
#
# GermlineMasterWF.bqsr.BqsrSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BashPreamble:
# 	File
#
# GermlineMasterWF.bqsr.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Sentieon:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.CenterName:
# 	String
#
# GermlineMasterWF.vqsr.VqsrSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.BqsrHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignEnvProfile:
# 	File
#
# GermlineMasterWF.vqsr.AnnotateText:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.RefPac:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSoftMemLimit:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.bqsr.Ref:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.BqsrKnownSites:
# 	String
#
# GermlineMasterWF.realign.RealignHardMemLimit:
# 	String
#
# GermlineMasterWF.dedup.DebugMode:
# 	String
#
# GermlineMasterWF.dedup.SentieonThreads:
# 	String
#
# GermlineMasterWF.bqsr.SentieonThreads:
# 	String
#
# GermlineMasterWF.haplotype.RefFai:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperEnvProfile:
# 	File
#
# GermlineMasterWF.realign.SentieonThreads:
# 	String
#
# GermlineMasterWF.MarkDuplicates:
# 	Boolean
#
# GermlineMasterWF.haplotype.BashPreamble:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefBwt:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Platform:
# 	String
#
# GermlineMasterWF.realign.RealignmentScript:
# 	File
#
# GermlineMasterWF.NormalInputReads:
# 	Array[Array[File]]
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.RefFai:
# 	File
#
# GermlineMasterWF.merge.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.realign.DebugMode:
# 	String
#
# GermlineMasterWF.DHVC.WorkflowJson:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimEnvProfile:
# 	File
#
# GermlineMasterWF.merge.MergeBamScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefSa:
# 	File
#
# GermlineMasterWF.bqsr.SampleName:
# 	String
#
# GermlineMasterWF.dedup.DedupScript:
# 	File
#
# GermlineMasterWF.haplotype.Ref:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.RefFai:
# 	File
#
# GermlineMasterWF.DAB.DebugMode:
# 	String
#
# GermlineMasterWF.dedup.Sentieon:
# 	String
#
# GermlineMasterWF.haplotype.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.Sentieon:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignmentScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefPac:
# 	File
#
# GermlineMasterWF.DAB.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.DHVC.DeliveryHaplotyperVC_Script:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperVCFSourceField:
# 	String
#
# GermlineMasterWF.haplotype.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignSoftMemLimit:
# 	String
#
# GermlineMasterWF.haplotype.DBSNP:
# 	File
#
# GermlineMasterWF.vqsr.VqsrIndelResourceString:
# 	String
#
# GermlineMasterWF.DHVC.DeliveryFolder_HaplotyperVC:
# 	String
#
# GermlineMasterWF.DAB.DeliveryFolder_Alignment:
# 	String
#
# GermlineMasterWF.vqsr.VqsrScript:
# 	File
#
# GermlineMasterWF.align.PlatformUnit:
# 	Array[String]
#
# GermlineMasterWF.align.ALIGN_paired.RefBwt:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.haplotype.HaplotyperScript:
# 	File
#
# GermlineMasterWF.Vqsr:
# 	Boolean
#
# GermlineMasterWF.vqsr.VqsrSnpResourceString:
# 	String
#
# GermlineMasterWF.dedup.DedupEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefAmb:
# 	File
#
# GermlineMasterWF.realign.BashPreamble:
# 	File
#
# GermlineMasterWF.DAB.SampleName:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.CenterName:
# 	String
#
# GermlineMasterWF.merge.SampleName:
# 	String
#
# GermlineMasterWF.realign.Sentieon:
# 	String
#
# GermlineMasterWF.bqsr.Sentieon:
# 	String
#
# GermlineMasterWF.vqsr.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.Platform:
# 	String
#
# GermlineMasterWF.realign.RealignmentKnownSites:
# 	String
#
# GermlineMasterWF.bqsr.BqsrScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignHardMemLimit:
# 	String
#
# GermlineMasterWF.DHVC.DebugMode:
# 	String
#
# GermlineMasterWF.haplotype.HaplotyperExtraOptionsString:
# 	String
#
# GermlineMasterWF.vqsr.VqsrEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignEnvProfile:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSeqScript:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdaptThreads:
# 	String
#
# GermlineMasterWF.bqsr.BqsrEnvProfile:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.BashPreamble:
# 	File
#
# GermlineMasterWF.vqsr.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BashPreamble:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.Library:
# 	String
#
# GermlineMasterWF.vqsr.Ref:
# 	File
#
# GermlineMasterWF.realign.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.SampleName:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSeqScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.AlignHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.SampleName:
# 	String
#
# GermlineMasterWF.DAB.DeliveryAlignment_Script:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.Ref:
# 	File
#
# GermlineMasterWF.haplotype.SampleName:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.Adapters:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Ref:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefSa:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.ChunkSizeInBases:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.RefAnn:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdaptThreads:
# 	String
#
# GermlineMasterWF.merge.SentieonThreads:
# 	String
#
# GermlineMasterWF.dedup.DedupHardMemLimit:
# 	String
#
# GermlineMasterWF.dedup.SampleName:
# 	String
#
# GermlineMasterWF.vqsr.RefFai:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefAnn:
# 	File
#
# GermlineMasterWF.DHVC.SampleName:
# 	String
#
# GermlineMasterWF.vqsr.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.align.ALIGN_single.Library:
# 	String
#
# GermlineMasterWF.bqsr.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdapt:
# 	String
#
# GermlineMasterWF.haplotype.Sentieon:
# 	String
#
# GermlineMasterWF.vqsr.SampleName:
# 	String
#
# GermlineMasterWF.merge.DebugMode:
# 	String
#
# GermlineMasterWF.DAB.WorkflowJson:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.align.SampleName:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.ChunkSizeInBases:
# 	String
#
# GermlineMasterWF.Trimming:
# 	Boolean
#
# GermlineMasterWF.vqsr.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdapt:
# 	String
#
# GermlineMasterWF.haplotype.DBSNPIdx:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.dedup.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.DAB.BashPreamble:
# 	File
#
# GermlineMasterWF.DHVC.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimEnvProfile:
# 	File
#
# GermlineMasterWF.realign.RealignEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefAmb:
# 	File
#
# GermlineMasterWF.haplotype.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BWAExtraOptionsString:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.AlignmentScript:
# 	File
#
# GermlineMasterWF.merge.MergeHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BWAExtraOptionsString:
# 	String
#
# GermlineMasterWF.vqsr.Sentieon:
# 	String
#
# GermlineMasterWF.merge.Sentieon:
# 	String
#
# GermlineMasterWF.merge.MergeSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.Ref:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.Adapters:
# 	File
#
# GermlineMasterWF.dedup.DedupSoftMemLimit:
# 	String
#
# GermlineMasterWF.merge.BashSharedFunctions:
# 	File

# %%
# demonstrate get_run_file_dict on json with quotes:
TestTask_dir = os.getcwd()
TestTask_jason_file = json_compare_file # json_filled_in #jsonTemplate # 'jjalltheway.json'

json_fullfilename = os.path.join(TestTask_dir, TestTask_jason_file)

print('File:\n%s\nwith method:\nget_json_file_dict\n\n'%(json_compare_file))

if os.path.isfile(json_fullfilename):
    json_template_dict = get_json_file_dict(json_fullfilename)
    print(type(json_template_dict))
    print('{0} variables found\n'.format(len(json_template_dict)))
    print(type(list(json_template_dict.keys())[0]))
    print(type(list(json_template_dict.values())[0]))
    print(list(json_template_dict.values())[0][0],'\n\n')
    if len(json_template_dict) > 0:
        for k, v in json_template_dict.items():
            print('%s:\n\t%s\n'%(k,v))
else:
    print(json_fullfilename, '\nNot Found')
# Out:
# File:
# ../data/GermlineParameters/Jsons/GermlineMasterWorkflow.template.json
# with method:
# get_json_file_dict
#
#
# <class 'dict'>
# 165 variables found
#
# <class 'str'>
# <class 'str'>
# S
#
#
# GermlineMasterWF.realign.RealignSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.DebugMode:
# 	String
#
# GermlineMasterWF.Bqsr:
# 	Boolean
#
# GermlineMasterWF.vqsr.VqsrHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.dedup.BashPreamble:
# 	File
#
# GermlineMasterWF.merge.MergeBamEnvProfile:
# 	File
#
# GermlineMasterWF.DHVC.BashPreamble:
# 	File
#
# GermlineMasterWF.bqsr.BqsrSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BashPreamble:
# 	File
#
# GermlineMasterWF.bqsr.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Sentieon:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.CenterName:
# 	String
#
# GermlineMasterWF.vqsr.VqsrSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.BqsrHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignEnvProfile:
# 	File
#
# GermlineMasterWF.vqsr.AnnotateText:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.RefPac:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSoftMemLimit:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.bqsr.Ref:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.BqsrKnownSites:
# 	String
#
# GermlineMasterWF.realign.RealignHardMemLimit:
# 	String
#
# GermlineMasterWF.dedup.DebugMode:
# 	String
#
# GermlineMasterWF.dedup.SentieonThreads:
# 	String
#
# GermlineMasterWF.bqsr.SentieonThreads:
# 	String
#
# GermlineMasterWF.haplotype.RefFai:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperEnvProfile:
# 	File
#
# GermlineMasterWF.realign.SentieonThreads:
# 	String
#
# GermlineMasterWF.MarkDuplicates:
# 	Boolean
#
# GermlineMasterWF.haplotype.BashPreamble:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefBwt:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Platform:
# 	String
#
# GermlineMasterWF.realign.RealignmentScript:
# 	File
#
# GermlineMasterWF.NormalInputReads:
# 	Array[Array[File]]
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.RefFai:
# 	File
#
# GermlineMasterWF.merge.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.realign.DebugMode:
# 	String
#
# GermlineMasterWF.DHVC.WorkflowJson:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimEnvProfile:
# 	File
#
# GermlineMasterWF.merge.MergeBamScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefSa:
# 	File
#
# GermlineMasterWF.bqsr.SampleName:
# 	String
#
# GermlineMasterWF.dedup.DedupScript:
# 	File
#
# GermlineMasterWF.haplotype.Ref:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.RefFai:
# 	File
#
# GermlineMasterWF.DAB.DebugMode:
# 	String
#
# GermlineMasterWF.dedup.Sentieon:
# 	String
#
# GermlineMasterWF.haplotype.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.Sentieon:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignmentScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefPac:
# 	File
#
# GermlineMasterWF.DAB.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.DHVC.DeliveryHaplotyperVC_Script:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperVCFSourceField:
# 	String
#
# GermlineMasterWF.haplotype.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignSoftMemLimit:
# 	String
#
# GermlineMasterWF.haplotype.DBSNP:
# 	File
#
# GermlineMasterWF.vqsr.VqsrIndelResourceString:
# 	String
#
# GermlineMasterWF.DHVC.DeliveryFolder_HaplotyperVC:
# 	String
#
# GermlineMasterWF.DAB.DeliveryFolder_Alignment:
# 	String
#
# GermlineMasterWF.vqsr.VqsrScript:
# 	File
#
# GermlineMasterWF.align.PlatformUnit:
# 	Array[String]
#
# GermlineMasterWF.align.ALIGN_paired.RefBwt:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.haplotype.HaplotyperScript:
# 	File
#
# GermlineMasterWF.Vqsr:
# 	Boolean
#
# GermlineMasterWF.vqsr.VqsrSnpResourceString:
# 	String
#
# GermlineMasterWF.dedup.DedupEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefAmb:
# 	File
#
# GermlineMasterWF.realign.BashPreamble:
# 	File
#
# GermlineMasterWF.DAB.SampleName:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.CenterName:
# 	String
#
# GermlineMasterWF.merge.SampleName:
# 	String
#
# GermlineMasterWF.realign.Sentieon:
# 	String
#
# GermlineMasterWF.bqsr.Sentieon:
# 	String
#
# GermlineMasterWF.vqsr.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.Platform:
# 	String
#
# GermlineMasterWF.realign.RealignmentKnownSites:
# 	String
#
# GermlineMasterWF.bqsr.BqsrScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignHardMemLimit:
# 	String
#
# GermlineMasterWF.DHVC.DebugMode:
# 	String
#
# GermlineMasterWF.haplotype.HaplotyperExtraOptionsString:
# 	String
#
# GermlineMasterWF.vqsr.VqsrEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignEnvProfile:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSeqScript:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdaptThreads:
# 	String
#
# GermlineMasterWF.bqsr.BqsrEnvProfile:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.BashPreamble:
# 	File
#
# GermlineMasterWF.vqsr.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BashPreamble:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.Library:
# 	String
#
# GermlineMasterWF.vqsr.Ref:
# 	File
#
# GermlineMasterWF.realign.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.SampleName:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSeqScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.AlignHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.SampleName:
# 	String
#
# GermlineMasterWF.DAB.DeliveryAlignment_Script:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.Ref:
# 	File
#
# GermlineMasterWF.haplotype.SampleName:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.Adapters:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Ref:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefSa:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.ChunkSizeInBases:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.RefAnn:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdaptThreads:
# 	String
#
# GermlineMasterWF.merge.SentieonThreads:
# 	String
#
# GermlineMasterWF.dedup.DedupHardMemLimit:
# 	String
#
# GermlineMasterWF.dedup.SampleName:
# 	String
#
# GermlineMasterWF.vqsr.RefFai:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefAnn:
# 	File
#
# GermlineMasterWF.DHVC.SampleName:
# 	String
#
# GermlineMasterWF.vqsr.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.align.ALIGN_single.Library:
# 	String
#
# GermlineMasterWF.bqsr.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdapt:
# 	String
#
# GermlineMasterWF.haplotype.Sentieon:
# 	String
#
# GermlineMasterWF.vqsr.SampleName:
# 	String
#
# GermlineMasterWF.merge.DebugMode:
# 	String
#
# GermlineMasterWF.DAB.WorkflowJson:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.align.SampleName:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.ChunkSizeInBases:
# 	String
#
# GermlineMasterWF.Trimming:
# 	Boolean
#
# GermlineMasterWF.vqsr.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdapt:
# 	String
#
# GermlineMasterWF.haplotype.DBSNPIdx:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.dedup.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.DAB.BashPreamble:
# 	File
#
# GermlineMasterWF.DHVC.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimEnvProfile:
# 	File
#
# GermlineMasterWF.realign.RealignEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefAmb:
# 	File
#
# GermlineMasterWF.haplotype.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BWAExtraOptionsString:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.AlignmentScript:
# 	File
#
# GermlineMasterWF.merge.MergeHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BWAExtraOptionsString:
# 	String
#
# GermlineMasterWF.vqsr.Sentieon:
# 	String
#
# GermlineMasterWF.merge.Sentieon:
# 	String
#
# GermlineMasterWF.merge.MergeSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.Ref:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.Adapters:
# 	File
#
# GermlineMasterWF.dedup.DedupSoftMemLimit:
# 	String
#
# GermlineMasterWF.merge.BashSharedFunctions:
# 	File

# %%
#                     Implement the current (Feb 2019 gitlab repo code)
import sys
import json
import logging

def read_json_file(json_file, 
                   project_logger=logging.getLogger(name='parse_test'), 
                   json_not_found_error_code="E.par.JSN.1", 
                   json_bad_format_error_code="E.par.JSN.2"):
    """ Usage: str_else_crash = read_json_file( json_file, 
                                                project_logger, 
                                                json_not_found_error_code, 
                                                json_bad_format_error_code)
    Reads a JSON formatted file, and returns its contents as a Python dictionary

    Inputs:
        The json file
        The project logger (for error messages to get passed to)
        The error code if a JSON file is not found
        The error code if a JSON file is improperly formatted
    """
    try:
        # Open the file
        with open(json_file) as F:
            # Read the file's contents as a string
            json_str = F.read()
            # Return the data as a Python dictionary
            return json.loads(json_str)
        
    except FileNotFoundError:
        project_logger.log_error(
            json_not_found_error_code,
            'Could not open json file "' + str(json_file) + '": JSON file could not be found'
        )
        sys.exit(1)
    except json.decoder.JSONDecodeError:
        project_logger.log_error(
            json_bad_format_error_code,
            'Could not open json file "' + str(json_file) + '": JSON file not formatted properly'
        )
        sys.exit(1)
        
# project_logger = logging.getLogger(name='any_name')
# json_not_found_error_code="E.par.JSN.1",
# json_bad_format_error_code="E.par.JSN.2"

# %%
print('File:\n%s\nwith method:\nread_json_file\n'%(json_compare_file))

dict_else_crash = read_json_file(json_compare_file)

print(type(dict_else_crash))
print('{0} variables found\n'.format(len(dict_else_crash)))
print(type(list(dict_else_crash.keys())[0]))
print(type(list(dict_else_crash.values())[0]))
print(list(dict_else_crash.values())[0][0],'\n\n')

for k, v in dict_else_crash.items():
    print('%s:\n\t%s\n'%(k,v))
# Out:
# File:
# ../data/GermlineParameters/Jsons/GermlineMasterWorkflow.template.json
# with method:
# read_json_file
#
# <class 'dict'>
# 165 variables found
#
# <class 'str'>
# <class 'str'>
# S
#
#
# GermlineMasterWF.realign.RealignSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.DebugMode:
# 	String
#
# GermlineMasterWF.Bqsr:
# 	Boolean
#
# GermlineMasterWF.vqsr.VqsrHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.dedup.BashPreamble:
# 	File
#
# GermlineMasterWF.merge.MergeBamEnvProfile:
# 	File
#
# GermlineMasterWF.DHVC.BashPreamble:
# 	File
#
# GermlineMasterWF.bqsr.BqsrSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BashPreamble:
# 	File
#
# GermlineMasterWF.bqsr.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Sentieon:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.CenterName:
# 	String
#
# GermlineMasterWF.vqsr.VqsrSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.BqsrHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignEnvProfile:
# 	File
#
# GermlineMasterWF.vqsr.AnnotateText:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.RefPac:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSoftMemLimit:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.bqsr.Ref:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.BqsrKnownSites:
# 	String
#
# GermlineMasterWF.realign.RealignHardMemLimit:
# 	String
#
# GermlineMasterWF.dedup.DebugMode:
# 	String
#
# GermlineMasterWF.dedup.SentieonThreads:
# 	String
#
# GermlineMasterWF.bqsr.SentieonThreads:
# 	String
#
# GermlineMasterWF.haplotype.RefFai:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperEnvProfile:
# 	File
#
# GermlineMasterWF.realign.SentieonThreads:
# 	String
#
# GermlineMasterWF.MarkDuplicates:
# 	Boolean
#
# GermlineMasterWF.haplotype.BashPreamble:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefBwt:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Platform:
# 	String
#
# GermlineMasterWF.realign.RealignmentScript:
# 	File
#
# GermlineMasterWF.NormalInputReads:
# 	Array[Array[File]]
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.RefFai:
# 	File
#
# GermlineMasterWF.merge.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.realign.DebugMode:
# 	String
#
# GermlineMasterWF.DHVC.WorkflowJson:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimEnvProfile:
# 	File
#
# GermlineMasterWF.merge.MergeBamScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefSa:
# 	File
#
# GermlineMasterWF.bqsr.SampleName:
# 	String
#
# GermlineMasterWF.dedup.DedupScript:
# 	File
#
# GermlineMasterWF.haplotype.Ref:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignSoftMemLimit:
# 	String
#
# GermlineMasterWF.bqsr.RefFai:
# 	File
#
# GermlineMasterWF.DAB.DebugMode:
# 	String
#
# GermlineMasterWF.dedup.Sentieon:
# 	String
#
# GermlineMasterWF.haplotype.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.Sentieon:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignmentScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefPac:
# 	File
#
# GermlineMasterWF.DAB.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.DHVC.DeliveryHaplotyperVC_Script:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperVCFSourceField:
# 	String
#
# GermlineMasterWF.haplotype.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.AlignSoftMemLimit:
# 	String
#
# GermlineMasterWF.haplotype.DBSNP:
# 	File
#
# GermlineMasterWF.vqsr.VqsrIndelResourceString:
# 	String
#
# GermlineMasterWF.DHVC.DeliveryFolder_HaplotyperVC:
# 	String
#
# GermlineMasterWF.DAB.DeliveryFolder_Alignment:
# 	String
#
# GermlineMasterWF.vqsr.VqsrScript:
# 	File
#
# GermlineMasterWF.align.PlatformUnit:
# 	Array[String]
#
# GermlineMasterWF.align.ALIGN_paired.RefBwt:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.haplotype.HaplotyperScript:
# 	File
#
# GermlineMasterWF.Vqsr:
# 	Boolean
#
# GermlineMasterWF.vqsr.VqsrSnpResourceString:
# 	String
#
# GermlineMasterWF.dedup.DedupEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefAmb:
# 	File
#
# GermlineMasterWF.realign.BashPreamble:
# 	File
#
# GermlineMasterWF.DAB.SampleName:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.CenterName:
# 	String
#
# GermlineMasterWF.merge.SampleName:
# 	String
#
# GermlineMasterWF.realign.Sentieon:
# 	String
#
# GermlineMasterWF.bqsr.Sentieon:
# 	String
#
# GermlineMasterWF.vqsr.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.Platform:
# 	String
#
# GermlineMasterWF.realign.RealignmentKnownSites:
# 	String
#
# GermlineMasterWF.bqsr.BqsrScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignHardMemLimit:
# 	String
#
# GermlineMasterWF.DHVC.DebugMode:
# 	String
#
# GermlineMasterWF.haplotype.HaplotyperExtraOptionsString:
# 	String
#
# GermlineMasterWF.vqsr.VqsrEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.AlignEnvProfile:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSeqScript:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdaptThreads:
# 	String
#
# GermlineMasterWF.bqsr.BqsrEnvProfile:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.BashPreamble:
# 	File
#
# GermlineMasterWF.vqsr.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BashPreamble:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.DebugMode:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.Library:
# 	String
#
# GermlineMasterWF.vqsr.Ref:
# 	File
#
# GermlineMasterWF.realign.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.SampleName:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSeqScript:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.AlignHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.SampleName:
# 	String
#
# GermlineMasterWF.DAB.DeliveryAlignment_Script:
# 	File
#
# GermlineMasterWF.haplotype.HaplotyperHardMemLimit:
# 	String
#
# GermlineMasterWF.realign.Ref:
# 	File
#
# GermlineMasterWF.haplotype.SampleName:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.Adapters:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.Ref:
# 	File
#
# GermlineMasterWF.align.ALIGN_single.RefSa:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.ChunkSizeInBases:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.RefAnn:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdaptThreads:
# 	String
#
# GermlineMasterWF.merge.SentieonThreads:
# 	String
#
# GermlineMasterWF.dedup.DedupHardMemLimit:
# 	String
#
# GermlineMasterWF.dedup.SampleName:
# 	String
#
# GermlineMasterWF.vqsr.RefFai:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefAnn:
# 	File
#
# GermlineMasterWF.DHVC.SampleName:
# 	String
#
# GermlineMasterWF.vqsr.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.align.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.align.ALIGN_single.Library:
# 	String
#
# GermlineMasterWF.bqsr.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdapt:
# 	String
#
# GermlineMasterWF.haplotype.Sentieon:
# 	String
#
# GermlineMasterWF.vqsr.SampleName:
# 	String
#
# GermlineMasterWF.merge.DebugMode:
# 	String
#
# GermlineMasterWF.DAB.WorkflowJson:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.PairedEnd:
# 	Boolean
#
# GermlineMasterWF.align.SampleName:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.ChunkSizeInBases:
# 	String
#
# GermlineMasterWF.Trimming:
# 	Boolean
#
# GermlineMasterWF.vqsr.BashPreamble:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdapt:
# 	String
#
# GermlineMasterWF.haplotype.DBSNPIdx:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.dedup.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.DAB.BashPreamble:
# 	File
#
# GermlineMasterWF.DHVC.BashSharedFunctions:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.DebugMode:
# 	String
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimEnvProfile:
# 	File
#
# GermlineMasterWF.realign.RealignEnvProfile:
# 	File
#
# GermlineMasterWF.align.ALIGN_paired.RefAmb:
# 	File
#
# GermlineMasterWF.haplotype.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.BWAExtraOptionsString:
# 	String
#
# GermlineMasterWF.align.ALIGN_paired.SentieonThreads:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.AlignmentScript:
# 	File
#
# GermlineMasterWF.merge.MergeHardMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.BWAExtraOptionsString:
# 	String
#
# GermlineMasterWF.vqsr.Sentieon:
# 	String
#
# GermlineMasterWF.merge.Sentieon:
# 	String
#
# GermlineMasterWF.merge.MergeSoftMemLimit:
# 	String
#
# GermlineMasterWF.align.ALIGN_single.Ref:
# 	File
#
# GermlineMasterWF.trimseq.TRIMSEQ_paired.Adapters:
# 	File
#
# GermlineMasterWF.dedup.DedupSoftMemLimit:
# 	String
#
# GermlineMasterWF.merge.BashSharedFunctions:
# 	File

# %%
print('File:\n%s\nwith method:\nget_config_file_dict\n'%(json_compare_file))

dict_else_crash = get_config_file_dict(json_compare_file)
# dict_else_crash = read_json_file(json_compare_file)
if len(dict_else_crash) > 0:
    print(type(dict_else_crash))
    print('{0} variables found\n'.format(len(dict_else_crash)))
    print(type(list(dict_else_crash.keys())[0]))
    print(type(list(dict_else_crash.values())[0]))
    print(list(dict_else_crash.values())[0][0],'\n\n')

    for k, v in dict_else_crash.items():
        print('%s:\n\t%s\n'%(k,v))
else:
    print('empty dictionary :) no "=" signs')
# Out:
# File:
# ../data/GermlineParameters/Jsons/GermlineMasterWorkflow.template.json
# with method:
# get_config_file_dict
#
# empty dictionary :) no "=" signs

# %%
dir()
# Out:
# ['Counter',
#  'In',
#  'OrderedDict',
#  'Out',
#  'TestTask_dir',
#  'TestTask_jason_file',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'argparse',
#  'args_dict_to_filledin_json',
#  'assemble_config_dict',
#  'configure_json_dict',
#  'defaultdict',
#  'dict_else_crash',
#  'dict_from_json_file',
#  'exit',
#  'get_config_file_dict',
#  'get_ipython',
#  'get_json_file_dict',
#  'get_json_keys_config_dict',
#  'json',
#  'jsonTemplate',
#  'json_compare_file',
#  'json_filled_in',
#  'json_fullfilename',
#  'json_template_dict',
#  'k',
#  'line',
#  'lines',
#  'logging',
#  'os',
#  'parse_args',
#  'path_to_development_code_modules',
#  'proppa_dict',
#  'quit',
#  'read_json_file',
#  'read_json_raw',
#  'read_raw_hee_haw',
#  'sys',
#  'v',
#  'write_filled_in_json_dict']

# %%
full_path_json = '../data/Jsons/GermlineMasterWorkflow.FilledIn.json'
if os.path.isfile(full_path_json):
    fp_json_dict = read_json_file(full_path_json)
for k, v in fp_json_dict.items():
    print(' key :\t%s\nvalue:\t%s\n%s\t%s\n'%(k,v,type(k),type(v)))
# Out:
#  key :	GermlineMasterWF.Bqsr
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DAB.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DAB.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DAB.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DAB.DeliveryAlignment_Script
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/deliver_alignment.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DAB.DeliveryFolder_Alignment
# value:	/projects/bioinformatics/DEL/Delivery/Alignment
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DAB.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DAB.WorkflowJson
# value:	/projects/bioinformatics/DEL/Jsons/GermlineMasterWorkflow.FilledIn.json
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DHVC.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DHVC.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DHVC.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DHVC.DeliveryFolder_HaplotyperVC
# value:	/projects/bioinformatics/DEL/Delivery/HaplotyperVC
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DHVC.DeliveryHaplotyperVC_Script
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/deliver_haplotyperVC.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DHVC.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.DHVC.WorkflowJson
# value:	/projects/bioinformatics/DEL/Jsons/GermlineMasterWorkflow.FilledIn.json
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.MarkDuplicates
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.NormalInputReads
# value:	[['/projects/bioinformatics/DEL/Inputs/WGS_chr1_5X_E0.005_L1_read1.fastq.gz', '/projects/bioinformatics/DEL/Inputs/WGS_chr1_5X_E0.005_L1_read2.fastq.gz'], ['/projects/bioinformatics/DEL/Inputs/WGS_chr1_5X_E0.005_L2_read1.fastq.gz', '/projects/bioinformatics/DEL/Inputs/WGS_chr1_5X_E0.005_L2_read2.fastq.gz']]
# <class 'str'>	<class 'list'>
#
#  key :	GermlineMasterWF.Trimming
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.Vqsr
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.AlignEnvProfile
# value:	/projects/bioinformatics/DEL/Config/AlignEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.AlignHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.AlignSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.AlignmentScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/alignment.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.BWAExtraOptionsString
# value:	"'-M'"
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.CenterName
# value:	some_seq_center
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.ChunkSizeInBases
# value:	10000000
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.Library
# value:	fake_lib
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.PairedEnd
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.Platform
# value:	ILLUMINA
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.Ref
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.RefAmb
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.amb
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.RefAnn
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.ann
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.RefBwt
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.bwt
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.RefDict
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.dict
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.RefPac
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.pac
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.RefSa
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.sa
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.Sentieon
# value:	/usr/local/apps/bioapps/sentieon/sentieon-genomics-201808.01
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_paired.SentieonThreads
# value:	40
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.AlignEnvProfile
# value:	/projects/bioinformatics/DEL/Config/AlignEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.AlignHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.AlignSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.AlignmentScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/alignment.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.BWAExtraOptionsString
# value:	"'-M'"
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.CenterName
# value:	some_seq_center
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.ChunkSizeInBases
# value:	10000000
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.Library
# value:	fake_lib
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.PairedEnd
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.Platform
# value:	ILLUMINA
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.Ref
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.RefAmb
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.amb
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.RefAnn
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.ann
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.RefBwt
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.bwt
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.RefDict
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.dict
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.RefPac
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.pac
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.RefSa
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.sa
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.Sentieon
# value:	/usr/local/apps/bioapps/sentieon/sentieon-genomics-201808.01
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.ALIGN_single.SentieonThreads
# value:	40
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.PairedEnd
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.align.PlatformUnit
# value:	['FLOWCELL_BARCODE.LANE.SAMPLE_BARCODE', 'FLOWCELL_BARCODE.LANE.SAMPLE_BARCODE']
# <class 'str'>	<class 'list'>
#
#  key :	GermlineMasterWF.bqsr.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.BqsrEnvProfile
# value:	/projects/bioinformatics/DEL/Config/BqsrEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.BqsrHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.BqsrKnownSites
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Mills_and_1000G_gold_standard.indels.hg38.vcf,/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.BqsrScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/bqsr.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.BqsrSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.Ref
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.RefAmb
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.amb
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.RefAnn
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.ann
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.RefBwt
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.bwt
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.RefDict
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.dict
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.RefFai
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.fai
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.RefPac
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.pac
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.RefSa
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.sa
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.Sentieon
# value:	/usr/local/apps/bioapps/sentieon/sentieon-genomics-201808.01
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.bqsr.SentieonThreads
# value:	40
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.DedupEnvProfile
# value:	/projects/bioinformatics/DEL/Config/DedupEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.DedupHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.DedupScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/dedup.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.DedupSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.Sentieon
# value:	/usr/local/apps/bioapps/sentieon/sentieon-genomics-201808.01
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.dedup.SentieonThreads
# value:	40
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.DBSNP
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.DBSNPIdx
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf.idx
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.HaplotyperEnvProfile
# value:	/projects/bioinformatics/DEL/Config/HaplotyperEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.HaplotyperExtraOptionsString
# value:	"'--emit_mode variant --gq_bands 1-60,60-99/19,99 --min_base_qual 10 --pcr_indel_model CONSERVATIVE --phasing 1 --ploidy 2 --prune_factor 2'"
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.HaplotyperHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.HaplotyperScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/haplotyper.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.HaplotyperSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.HaplotyperVCFSourceField
# value:	/projects/bioinformatics/DEL/Config/HaplotyperVCFSourceField.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.Ref
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.RefAmb
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.amb
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.RefAnn
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.ann
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.RefBwt
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.bwt
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.RefDict
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.dict
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.RefFai
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.fai
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.RefPac
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.pac
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.RefSa
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.sa
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.Sentieon
# value:	/usr/local/apps/bioapps/sentieon/sentieon-genomics-201808.01
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.haplotype.SentieonThreads
# value:	40
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.MergeBamEnvProfile
# value:	/projects/bioinformatics/DEL/Config/MergeBamEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.MergeBamScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/merge_bams.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.MergeHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.MergeSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.Sentieon
# value:	/usr/local/apps/bioapps/sentieon/sentieon-genomics-201808.01
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.merge.SentieonThreads
# value:	40
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RealignEnvProfile
# value:	/projects/bioinformatics/DEL/Config/RealignEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RealignHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RealignSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RealignmentKnownSites
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Mills_and_1000G_gold_standard.indels.hg38.vcf
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RealignmentScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/realignment.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.Ref
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RefAmb
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.amb
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RefAnn
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.ann
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RefBwt
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.bwt
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RefDict
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.dict
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RefFai
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.fai
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RefPac
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.pac
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.RefSa
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.sa
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.Sentieon
# value:	/usr/local/apps/bioapps/sentieon/sentieon-genomics-201808.01
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.realign.SentieonThreads
# value:	40
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.PairedEnd
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.Adapters
# value:	/projects/bioinformatics/DEL/Inputs/TruSeqAdaptors.fasta
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdapt
# value:	/usr/local/apps/bioapps/python/Python-3.6.1/bin
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.CutAdaptThreads
# value:	8
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.PairedEnd
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimEnvProfile
# value:	/projects/bioinformatics/DEL/Config/TrimEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSeqScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/trim_sequences.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_paired.TrimSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.Adapters
# value:	/projects/bioinformatics/DEL/Inputs/TruSeqAdaptors.fasta
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdapt
# value:	/usr/local/apps/bioapps/python/Python-3.6.1/bin
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.CutAdaptThreads
# value:	8
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.PairedEnd
# value:	true
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.TrimEnvProfile
# value:	/projects/bioinformatics/DEL/Config/TrimEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.TrimHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSeqScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/trim_sequences.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.trimseq.TRIMSEQ_single.TrimSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.AnnotateText
# value:	"'--annotation DP --annotation QD --annotation FS --annotation SOR --annotation MQ --annotation MQRankSum --annotation ReadPosRankSum'"
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.BashPreamble
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shell_preamble.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.BashSharedFunctions
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/shared_functions.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.DebugMode
# value:
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.Ref
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.RefAmb
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.amb
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.RefAnn
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.ann
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.RefBwt
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.bwt
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.RefDict
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.dict
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.RefFai
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.fai
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.RefPac
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.pac
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.RefSa
# value:	/projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Homo_sapiens_assembly38.fasta.sa
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.SampleName
# value:	WGS_chr1_5X_E0.005_chunk1
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.Sentieon
# value:	/usr/local/apps/bioapps/sentieon/sentieon-genomics-201808.01
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.SentieonThreads
# value:	40
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.VqsrEnvProfile
# value:	/projects/bioinformatics/DEL/Config/VqsrEnvProfile.file
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.VqsrHardMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.VqsrIndelResourceString
# value:	"'--resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf --resource_param dbsnp,known=true,training=false,truth=false,prior=2.0 --resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/Mills_and_1000G_gold_standard.indels.hg38.vcf --resource_param Mills,known=false,training=true,truth=true,prior=12.0'"
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.VqsrScript
# value:	/projects/bioinformatics/DEL/MayomicsVC/src/shell/vqsr.sh
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.VqsrSnpResourceString
# value:	"'--resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/1000G_phase1.snps.high_confidence.hg38.vcf.gz --resource_param 1000G,known=false,training=true,truth=false,prior=10.0 --resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/1000G_omni2.5.hg38.vcf.gz --resource_param omni,known=false,training=true,truth=false,prior=12.0 --resource /projects/mgc/Project_1/MayomicsVC_MayoTesting/Reference/dbsnp_138.hg38.vcf --resource_param dbsnp,known=true,training=false,truth=false,prior=2.0 --resource /projects/bioinformatics/DataPacks/human/gatk_bundle_Oct_2017/gatk_bundle_hg38/hapmap_3.3.hg38.vcf.gz --resource_param hapmap,known=false,training=true,truth=true,prior=15.0'"
# <class 'str'>	<class 'str'>
#
#  key :	GermlineMasterWF.vqsr.VqsrSoftMemLimit
# value:	100G
# <class 'str'>	<class 'str'>
